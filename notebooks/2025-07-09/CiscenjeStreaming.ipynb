# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from utils import apply_iqr_capping

# %%
streaming_df = pd.read_csv("../../datasets/streaming.csv")

# %%
streaming_df
# Out:
#      Unnamed: 0  KorisnikID  Starost_Korisnika  Broj_Pogledanih_Sati_Mjesecno  \
# 0             0        1001                 52                           13.9
# 1             1        1002                 34                            2.5
# 2             2        1003                 26                           36.4
# 3             3        1004                 21                           44.1
# 4             4        1005                 30                           15.6
# ..          ...         ...                ...                            ...
# 195         195        1196                 21                           10.2
# 196         196        1197                 20                           25.6
# 197         197        1198                 20                           21.9
# 198         198        1199                 21                           10.9
# 199         199        1200                 33                           37.6
#
# ...

# %%
streaming_df.loc[streaming_df["Starost_Korisnika"] < 18]
# Out:
#      Unnamed: 0  KorisnikID  Starost_Korisnika  Broj_Pogledanih_Sati_Mjesecno  \
# 55           55        1056                 -5                            8.8
# 158         158        1159                  1                           21.5
#
#      Broj_Uredjaja Tip_Pretplata  Mjesecna_Pretplata_EUR
# 55               2      Standard                   15.49
# 158              2       Premium                   21.67
